# %%
from astropy.table import Table
from astropy.io import fits

# %%
file_path = '/Users/zhurui/Research/data/eBOSS_ELG_full_ALLdata-vDR16.fits'
t = Table.read(file_path, character_as_bytes=False)
t
# Out:
# WARNING: UnitsWarning: 'erg/s/cm2' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# <Table length=269178>
#         RA                DEC         ...   comb_galdepth    chunk_z
#      degrees            degrees       ...
#      float64            float64       ...      float64        int16
# ------------------ ------------------ ... ------------------ -------
# 340.98805601625793 0.6223024540762905 ... 0.8384311396963411       1
#  340.9582713928849 0.9950635055224771 ...  0.844253704924937       2
# 340.90939586134937 0.3906087364256986 ... 0.8460403582924767       0
# 340.83989176727374 0.4802944287712422 ... 0.8390648482169756       0
# 340.81530989798864 0.4937404374234702 ... 0.8463076420023555       3
# 340.83980022059495 0.5671354965043504 ... 0.8441145297926923       2
#  340.8694612833357 0.6792396645080305 ... 0.8428916422859072       0
#   341.013580073137 0.6595723021310284 ... 0.8458758512260838       0
# ...

# %%
df = Table(df.as_array())
df = df.to_pandas()

# %% [markdown]
# # 写入fits
# <mark> asd

# %%
t.write('existing_table.fits', overwrite=True)
